# %% [markdown]
# # Pengujian Menggunakan Pustaka Buatan
#
# Convex Hull dibuat dengan menggunakan pustaka myConvexHull yang terdapat dalam file myConvexHull.py

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from myConvexHull import myConvexHull

# %% [markdown]
# ## Convex Hull untuk atribut Petal-length dan Petal-width pada dataset Iris

# %%
data1 = datasets.load_iris()

df = pd.DataFrame(data1.data, columns=data1.feature_names) 
df['Target'] = pd.DataFrame(data1.target) 
plt.figure(figsize = (10, 6))
colors = ['b','r','g']
plt.title('Petal-length vs Petal-width')
plt.xlabel(data1.feature_names[2])
plt.ylabel(data1.feature_names[3])
for i in range(len(data1.target_names)):
    bucket = df[df['Target'] == i]
    bucket = bucket.iloc[:,[2,3]].values
    hull = myConvexHull(bucket) #bagian ini diganti dengan hasil implementasi ConvexHull Divide & Conquer
    plt.scatter(bucket[:, 0], bucket[:, 1], label=data1.target_names[i])
    for line in hull.lines:  
        plt.plot([line[0][0], line[1][0]], [line[0][1], line[1][1]], colors[i])
plt.legend()
plt.show()

# %% [markdown]
# ## Convex Hull untuk atribut Sepal-length dan Sepal-width pada dataset Iris

# %%
data2 = datasets.load_iris()

df = pd.DataFrame(data2.data, columns=data2.feature_names) 
df['Target'] = pd.DataFrame(data2.target) 
plt.figure(figsize = (10, 6))
colors = ['b','r','g']
plt.title('Sepal-length vs Sepal-width')
plt.xlabel(data2.feature_names[0])
plt.ylabel(data2.feature_names[1])
for i in range(len(data2.target_names)):
    bucket = df[df['Target'] == i]
    bucket = bucket.iloc[:,[0,1]].values
    hull = myConvexHull(bucket) #bagian ini diganti dengan hasil implementasi ConvexHull Divide & Conquer
    plt.scatter(bucket[:, 0], bucket[:, 1], label=data2.target_names[i])
    for line in hull.lines:  
        plt.plot([line[0][0], line[1][0]], [line[0][1], line[1][1]], colors[i])
plt.legend()
plt.show()

# %% [markdown]
# ## Convex Hull untuk atribut Alcohol dan Malic Acid pada dataset Wine

# %%
data3 = datasets.load_wine()

df = pd.DataFrame(data3.data, columns=data3.feature_names) 
df['Target'] = pd.DataFrame(data3.target) 
plt.figure(figsize = (10, 6))
colors = ['b','r','g']
plt.title('Alcohol vs Malic Acid')
plt.xlabel(data3.feature_names[0])
plt.ylabel(data3.feature_names[1])
for i in range(len(data3.target_names)):
    bucket = df[df['Target'] == i]
    bucket = bucket.iloc[:,[0,1]].values
    hull = myConvexHull(bucket) #bagian ini diganti dengan hasil implementasi ConvexHull Divide & Conquer
    plt.scatter(bucket[:, 0], bucket[:, 1], label=data3.target_names[i])
    for line in hull.lines:  
        plt.plot([line[0][0], line[1][0]], [line[0][1], line[1][1]], colors[i])
plt.legend()
plt.show()

# %% [markdown]
# ## Convex Hull untuk atribut Color Intensity dan Hue pada dataset Wine

# %%
data4 = datasets.load_wine()

df = pd.DataFrame(data4.data, columns=data4.feature_names) 
df['Target'] = pd.DataFrame(data4.target) 
plt.figure(figsize = (10, 6))
colors = ['b','r','g']
plt.title('Color Intensity vs Hue')
plt.xlabel(data4.feature_names[9])
plt.ylabel(data4.feature_names[10])
for i in range(len(data4.target_names)):
    bucket = df[df['Target'] == i]
    bucket = bucket.iloc[:,[9,10]].values
    hull = myConvexHull(bucket) #bagian ini diganti dengan hasil implementasi ConvexHull Divide & Conquer
    plt.scatter(bucket[:, 0], bucket[:, 1], label=data4.target_names[i])
    for line in hull.lines:  
        plt.plot([line[0][0], line[1][0]], [line[0][1], line[1][1]], colors[i])
plt.legend()
plt.show()

# %% [markdown]
# ## Convex Hull untuk atribut Radius dan Smoothness pada dataset Breast Cancer

# %%
data5 = datasets.load_breast_cancer()

df = pd.DataFrame(data5.data, columns=data5.feature_names) 
df['Target'] = pd.DataFrame(data5.target) 
plt.figure(figsize = (10, 6))
colors = ['b','r','g']
plt.title('Radius vs Smoothness')
plt.xlabel(data5.feature_names[0])
plt.ylabel(data5.feature_names[4])
for i in range(len(data5.target_names)):
    bucket = df[df['Target'] == i]
    bucket = bucket.iloc[:,[0,4]].values
    hull = myConvexHull(bucket) #bagian ini diganti dengan hasil implementasi ConvexHull Divide & Conquer
    plt.scatter(bucket[:, 0], bucket[:, 1], label=data5.target_names[i])
    for line in hull.lines:  
        plt.plot([line[0][0], line[1][0]], [line[0][1], line[1][1]], colors[i])
plt.legend()
plt.show()

# %% [markdown]
# ## Convex Hull untuk atribut Symmetry dan Fractal Dimension pada dataset Breast Cancer

# %%
ata6 = datasets.load_breast_cancer()

df = pd.DataFrame(data6.data, columns=data6.feature_names) 
df['Target'] = pd.DataFrame(data6.target) 
plt.figure(figsize = (10, 6))
colors = ['b','r','g']
plt.title('Symmetry vs Fractal Dimension')
plt.xlabel(data6.feature_names[8])
plt.ylabel(data6.feature_names[9])
for i in range(len(data6.target_names)):
    bucket = df[df['Target'] == i]
    bucket = bucket.iloc[:,[8,9]].values
    hull = myConvexHull(bucket) #bagian ini diganti dengan hasil implementasi ConvexHull Divide & Conquer
    plt.scatter(bucket[:, 0], bucket[:, 1], label=data6.target_names[i])
    for line in hull.lines:  
        plt.plot([line[0][0], line[1][0]], [line[0][1], line[1][1]], colors[i])
plt.legend()
plt.show()
